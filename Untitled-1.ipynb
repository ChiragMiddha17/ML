# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pexels-pixabay-60597.jpg')

# %%
img
# Out:
# array([[[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]],
#
#        [[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]],
#
#        [[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]],
#
#        ...,
#
#        [[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]],
#
#        [[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]],
#
#        [[40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25],
#         ...,
#         [40, 51, 25],
#         [40, 51, 25],
#         [40, 51, 25]]], dtype=uint8)

# %%
img.shape
# Out:
# (2736, 3648, 3)

# %%
cv2.imshow('Image' , img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
img1 = plt.imread('pexels-pixabay-60597.jpg')
plt.imshow(img1)

# %%
img2 = ski.io.imread('pexels-pixabay-60597.jpg')
ski.io.imshow(img2)

# %%
ski.io.imsave('pexels-pixabay-60597.jpg',img)
plt.imsave('pexels-pixabay-60597.jpg',img)
cv2.imwrite('pexels-pixabay-60597.jpg',img)
# Out:
# True

# %%
cv2.COLOR_RGB2GRAY
# Out:
# 7

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray)

# %%
_, img_binary = cv2.threshold(img_gray , 50 , 255 , cv2.THRESH_BINARY)
ski.io.imshow(img_binary , )
